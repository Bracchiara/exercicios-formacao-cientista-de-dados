# %%
import pandas as pd
import seaborn as sns

# %%
base = pd.read_csv('dados.csv', sep = ';')
base
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
# Verificar a distribuição do valor pib
sns.histplot(base.PIB, kde=True, bins=10).set(title='PIB')
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
# Verificar a distribuição do valorempenho
sns.histplot(base.VALOREMPENHO, kde=True, bins=10).set(title='VALOREMPENHO')
# Out:
# [Text(0.5, 1.0, 'VALOREMPENHO')]

# %%
# 10 menores pibs em gráfico de barras
pib = base.sort_values('PIB').head(10)
pib = pib.iloc[:, 1: 3]
pib
pib.plot.bar(x='MUNICIPIO', y='PIB', color = 'green')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
# 10 maiores pibs em gráfico de barras
pib = base.sort_values('PIB').tail(10)
pib = pib.iloc[:, 1: 3]
pib

pib.plot.bar(x = 'MUNICIPIO', y = 'PIB', color = 'purple')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
# 10 maiores valorempenho em gráfico de barras
valorempenho = base.sort_values('VALOREMPENHO').head(10)
valorempenho = valorempenho.iloc[:, [1, 3]]
valorempenho

valorempenho.plot.bar(x = 'MUNICIPIO', y= 'VALOREMPENHO', color = 'red')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
# 10 menores valorempenho em gráfico de barras
valorempenho = base.sort_values('VALOREMPENHO').tail(10)
valorempenho = valorempenho.iloc[:, [1, 3]]
valorempenho

valorempenho.plot.bar(x = 'MUNICIPIO', y = 'VALOREMPENHO', color = 'orange')
# Out:
# <Axes: xlabel='MUNICIPIO'>
